# %%
# The typical imports
import gym
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Imports specifically so we can render outputs in Jupyter.
from JSAnimation.IPython_display import display_animation
from matplotlib import animation
from IPython.display import display

# to be viewed in jupyter
def display_frames_as_gif(frames):
    """
    Displays a list of frames as a gif, with controls
    """
    #plt.figure(figsize=(frames[0].shape[1] / 72.0, frames[0].shape[0] / 72.0), dpi = 72)
    patch = plt.imshow(frames[0])
    plt.axis('off')

    def animate(i):
        patch.set_data(frames[i])

    anim = animation.FuncAnimation(plt.gcf(), animate, frames = len(frames), interval=20)
    display(display_animation(anim, default_mode='loop'))

# %%
env = gym.make('LunarLander-v2')

# Run a demo of the environment
observation = env.reset()
cum_reward = 0
frames = []
for t in range(5000):
    # Render into buffer. 
    frames.append(env.render(mode = 'rgb_array'))
    action = env.action_space.sample()
    observation, reward, done, info = env.step(action)
    if done:
        break
env.close()
display_frames_as_gif(frames)
# Out:
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src = this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_forward();}, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_reverse();}, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgRMFRAEQZYERLYFDB">
#     <br>
#     <input id="_anim_sliderRMFRAEQZYERLYFDB" type="range" style="width:350px" name="points" min="0" max="1" step="1" value="0" onchange="animRMFRAEQZYERLYFDB.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animRMFRAEQZYERLYFDB.slower()">&#8211;</button>
#     <button onclick="animRMFRAEQZYERLYFDB.first_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animRMFRAEQZYERLYFDB.previous_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animRMFRAEQZYERLYFDB.reverse_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animRMFRAEQZYERLYFDB.pause_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="animRMFRAEQZYERLYFDB.play_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animRMFRAEQZYERLYFDB.next_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animRMFRAEQZYERLYFDB.last_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animRMFRAEQZYERLYFDB.faster()">+</button>
#   <form action="#n" name="_anim_loop_selectRMFRAEQZYERLYFDB" class="anim_control">
#     <input type="radio" name="state" value="once" > Once </input>
#     <input type="radio" name="state" value="loop" checked> Loop </input>
#     <input type="radio" name="state" value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgRMFRAEQZYERLYFDB";
#     var slider_id = "_anim_sliderRMFRAEQZYERLYFDB";
#     var loop_select_id = "_anim_loop_selectRMFRAEQZYERLYFDB";
#     var frames = new Array(0);
#
#   frames[0] = "data:image/png;base64,..."
#   frames[1] = "data:image/png;base64,..."
#   frames[2] = "data:image/png;base64,..."
#   frames[3] = "data:image/png;base64,..."
#   frames[4] = "data:image/png;base64,..."
#   frames[5] = "data:image/png;base64,..."
#   frames[6] = "data:image/png;base64,..."
#   frames[7] = "data:image/png;base64,..."
#   frames[8] = "data:image/png;base64,..."
#   frames[9] = "data:image/png;base64,..."
#   frames[10] = "data:image/png;base64,..."
#   frames[11] = "data:image/png;base64,..."
#   frames[12] = "data:image/png;base64,..."
#   frames[13] = "data:image/png;base64,..."
#   frames[14] = "data:image/png;base64,..."
#   frames[15] = "data:image/png;base64,..."
#   frames[16] = "data:image/png;base64,..."
#   frames[17] = "data:image/png;base64,..."
#   frames[18] = "data:image/png;base64,..."
#   frames[19] = "data:image/png;base64,..."
#   frames[20] = "data:image/png;base64,..."
#   frames[21] = "data:image/png;base64,..."
#   frames[22] = "data:image/png;base64,..."
#   frames[23] = "data:image/png;base64,..."
#   frames[24] = "data:image/png;base64,..."
#   frames[25] = "data:image/png;base64,..."
#   frames[26] = "data:image/png;base64,..."
#   frames[27] = "data:image/png;base64,..."
#   frames[28] = "data:image/png;base64,..."
#   frames[29] = "data:image/png;base64,..."
#   frames[30] = "data:image/png;base64,..."
#   frames[31] = "data:image/png;base64,..."
#   frames[32] = "data:image/png;base64,..."
#   frames[33] = "data:image/png;base64,..."
#   frames[34] = "data:image/png;base64,..."
#   frames[35] = "data:image/png;base64,..."
#   frames[36] = "data:image/png;base64,..."
#   frames[37] = "data:image/png;base64,..."
#   frames[38] = "data:image/png;base64,..."
#   frames[39] = "data:image/png;base64,..."
#   frames[40] = "data:image/png;base64,..."
#   frames[41] = "data:image/png;base64,..."
#   frames[42] = "data:image/png;base64,..."
#   frames[43] = "data:image/png;base64,..."
#   frames[44] = "data:image/png;base64,..."
#   frames[45] = "data:image/png;base64,..."
#   frames[46] = "data:image/png;base64,..."
#   frames[47] = "data:image/png;base64,..."
#   frames[48] = "data:image/png;base64,..."
#   frames[49] = "data:image/png;base64,..."
#   frames[50] = "data:image/png;base64,..."
#   frames[51] = "data:image/png;base64,..."
#   frames[52] = "data:image/png;base64,..."
#   frames[53] = "data:image/png;base64,..."
#   frames[54] = "data:image/png;base64,..."
#   frames[55] = "data:image/png;base64,..."
#   frames[56] = "data:image/png;base64,..."
#   frames[57] = "data:image/png;base6

# %%
env = gym.make('LunarLander-v2')
num_episodes=40
for i_episode in range(num_episodes):
    sum_reward = 0
    observation = env.reset()
    for t in range(500):
        action = env.action_space.sample() # random action
        observation, reward, done, info = env.step(action)
        sum_reward += reward
        if done:
            print("Episode {}/{} finished after {} timesteps with {} reward\n".format(i_episode, num_episodes, t+1, sum_reward), end="")
            break
print(observation)
# Out:
# Episode 0/40 finished after 89 timesteps with -358.24893577776936 reward
# Episode 1/40 finished after 89 timesteps with -494.81119481856956 reward
# Episode 2/40 finished after 117 timesteps with -88.31557689988611 reward
# Episode 3/40 finished after 89 timesteps with -284.39344626409127 reward
# Episode 4/40 finished after 83 timesteps with -82.96773652816928 reward
# Episode 5/40 finished after 94 timesteps with -316.91953050224356 reward
# Episode 6/40 finished after 94 timesteps with -240.51809717008703 reward
# Episode 7/40 finished after 102 timesteps with -356.0478342936131 reward
# Episode 8/40 finished after 90 timesteps with -110.76133685005081 reward
# Episode 9/40 finished after 120 timesteps with -170.56105221742135 reward
# Episode 10/40 finished after 94 timesteps with -246.8110717515373 reward
# Episode 11/40 finished after 88 timesteps with -179.73562998053103 reward
# Episode 12/40 finished after 88 timesteps with -141.90560689827856 reward
# Episode 13/40 finished after 118 timesteps with -419.618947116271 reward
# Episode 14/40 finished after 104 timesteps with -352.3027892328672 reward
# Episode 15/40 finished after 110 timesteps with -357.1448870455622 reward
# Episode 16/40 finished after 65 timesteps with -87.25062070461404 reward
# Episode 17/40 finished after 97 timesteps with -33.93237012658122 reward
# Episode 18/40 finished after 64 timesteps with -268.43789832002005 reward
# Episode 19/40 finished after 96 timesteps with -421.79747770965406 reward
# Episode 20/40 finished after 75 timesteps with -72.46721970544698 reward
# Episode 21/40 finished after 66 timesteps with -80.42660422080478 reward
# Episode 22/40 finished after 103 timesteps with 14.857497729465862 reward
# Episode 23/40 finished after 57 timesteps with -216.12573729760567 reward
# Episode 24/40 finished after 120 timesteps with -213.1073196672029 reward
# Episode 25/40 finished after 105 timesteps with -292.8816365483817 reward
# Episode 26/40 finished after 88 timesteps with -311.51338084606243 reward
# Episode 27/40 finished after 89 timesteps with -360.2458364270113 reward
# Episode 28/40 finished after 107 timesteps with -136.69631446742738 reward
# Episode 29/40 finished after 105 timesteps with -232.26670569001868 reward
# Episode 30/40 finished after 65 timesteps with -56.7776998056421 reward
# Episode 31/40 finished after 71 timesteps with -105.76801742263213 reward
# Episode 32/40 finished after 62 timesteps with -241.87228984996483 reward
# Episode 33/40 finished after 115 timesteps with -148.81170695516167 reward
# Episode 34/40 finished after 120 timesteps with -196.3399675462744 reward
# Episode 35/40 finished after 65 timesteps with -190.439811283512 reward
# Episode 36/40 finished after 88 timesteps with -476.20702143255033 reward
# Episode 37/40 finished after 71 timesteps with -88.13995699360544 reward
# Episode 38/40 finished after 119 timesteps with -178.47495162202546 reward
# Episode 39/40 finished after 92 timesteps with -308.4092919096431 reward
# [ 0.8933296  -0.03449724  0.46227407  0.21634783 -1.7990267  -1.6964155
#   1.          0.        ]
